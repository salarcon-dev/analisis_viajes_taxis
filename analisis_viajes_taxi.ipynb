# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general del revisor</b> <a class="tocSkip"></a><br />
# Status del proyecto: <b>Aprobado</b>
# </div>

# %% [markdown]
# ¡Hola!<br />
# Soy **Francisco Cortés**, estoy contento de revisar tu proyecto y ser parte de tu proceso de aprendizaje.
# A lo largo del texto, haré algunas observaciones sobre mejoras en el código y también haré comentarios sobre tus percepciones sobre el tema. Si existe algún error en el código, no te preocupes, estoy aquí para ayudarte a mejorarlo, en la primera iteración te lo señalaré para que tengas la oportunidad de corregirlo, pero si aún no encuentras una solución para esta tarea, te daré una pista más precisa en la próxima iteración y también algunos ejemplos prácticos. Estaré abierto a retroalimentación y discusiones sobre el tema.<br />
# Encontrarás mis comentarios a continuación - **por favor no los muevas, modifiques o borres**.
# Revisaré cuidadosamente tu código para comprobar que se han cumplido con los requisitos y te proporcionaré mis comentarios en cajas verdes, amarillas o rojas como esta:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si la ejecución fue perfecta succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si existe alguna recomendación para que tu código mejore.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si existen correcciones necesarias para cumplir con los requisitos. El trabajo no puede ser aceptado si hay alguna caja roja.
# </div>
#
# Puedes responderme de la siguiente manera:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante.</b> <a class="tocSkip"></a>
# </div>

# %%
# Paso 1: Importar bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# Paso 2: Importar los archivos CSV
df_companies = pd.read_csv('/datasets/project_sql_result_01.csv')
df_locations = pd.read_csv('/datasets/project_sql_result_04.csv')

# Paso 3: Examinar datos
print(df_companies.info())
print(df_companies.head())

print(df_locations.info())
print(df_locations.head())

# Paso 4: Verificar valores nulos
print("Valores nulos en compañías:\n", df_companies.isnull().sum())
print("Valores nulos en barrios:\n", df_locations.isnull().sum())

# Paso 5: Verificar tipos de datos
print("Tipos de datos en compañías:\n", df_companies.dtypes)
print("Tipos de datos en barrios:\n", df_locations.dtypes)

# Paso 6: Top 10 compañías de taxis por cantidad de viajes
top_companies = df_companies.sort_values(by='trips_amount', ascending=False).head(10)

# Paso 7: Top 10 barrios por promedio de viajes finalizados
top_locations = df_locations.sort_values(by='average_trips', ascending=False).head(10)

# Paso 8: Visualizar compañías
plt.figure(figsize=(10, 5))
plt.bar(top_companies['company_name'], top_companies['trips_amount'])
plt.title('Top 10 compañías de taxi por cantidad de viajes (15-16 nov 2017)')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Cantidad de viajes')
plt.tight_layout()
plt.show()

# Paso 9: Visualizar barrios
plt.figure(figsize=(10, 5))
plt.bar(top_locations['dropoff_location_name'], top_locations['average_trips'])
plt.title('Top 10 barrios por promedio de viajes finalizados (nov 2017)')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Promedio de viajes')
plt.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  64 non-null     object
#  1   trips_amount  64 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB
# None
#                       company_name  trips_amount
# 0                        Flash Cab         19558
# 1        Taxi Affiliation Services         11422
# 2                Medallion Leasing         10367
# 3                       Yellow Cab          9888
# 4  Taxi Affiliation Service Yellow          9299
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dropoff_location_name  94 non-null     object
#  1   average_trips          94 non-null     float64
# dtypes: float64(1), object(1)
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# Correcto!<br/>
#
# Buena manera de mostrar los resultados, se pueden observar claramente los resultados ya que en ambos casos limitaste el número de elementos que se muestran
# </div>

# %% [markdown]
# ## Conclusiones del Análisis Exploratorio (Paso 4)
#
# ### Top 10 compañías de taxi por cantidad de viajes (15-16 de noviembre de 2017):
#
# - **Flash Cab** fue la empresa con más viajes en los días analizados, con casi **20,000 servicios realizados**.
# - Le siguen **Taxi Affiliation Services**, **Medallion Leasing** y **Yellow Cab**, todas con más de **9,000 viajes**.
# - La diferencia entre las primeras tres compañías y el resto es significativa, lo que indica una **alta concentración de demanda** en unas pocas empresas.
# - Las empresas en los últimos lugares del top 10 realizaron entre **7,000 y 8,000 viajes**.
#
# > **Conclusión:** unas pocas compañías dominan el mercado de taxis en Chicago en esos días específicos.
#
# ---
#
# ### Top 10 barrios por promedio de viajes finalizados (noviembre 2017):
#
# - **Loop** destaca como el barrio con mayor promedio de finalizaciones de viajes (**más de 10,000**), indicando su papel central como destino frecuente.
# - **River North** y **Streeterville** también muestran una alta demanda, con promedios de **más de 6,000 viajes**.
# - Otros barrios como **West Loop**, **O'Hare** y **Lake View** tienen valores considerables, aunque más bajos.
# - Los últimos del top 10, como **Gold Coast** y **Sheffield & DePaul**, registran promedios menores a **2,000 viajes**.
#
# > **Conclusión:** los barrios céntricos y de alto tránsito comercial o turístico concentran la mayoría de las llegadas en taxi.
#
# ---
#
# ### Explicación del análisis:
#
# - Se utilizaron dos archivos CSV que contienen datos de empresas de taxis y destinos de viajes en Chicago.
# - Se importaron y verificaron los tipos de datos, asegurando que no hubiera valores nulos.
# - Se identificaron patrones claros:
#   - **Concentración de viajes en pocas compañías.**
#   - **Mayor número de viajes finalizados en zonas céntricas.**
# - Estos hallazgos pueden servir para:
#   - Optimizar la asignación de flotas.
#   - Ajustar estrategias comerciales por zonas.
#   - Entender la dinámica de demanda urbana en el servicio de taxis.

# %%
import pandas as pd
from scipy import stats

# Paso 1: Cargar el archivo CSV
df = pd.read_csv('/datasets/project_sql_result_07.csv')

# Paso 2: Asegurarse de que start_ts sea un datetime
df['start_ts'] = pd.to_datetime(df['start_ts'])

# Paso 3: Filtrar solo los viajes que se hicieron en sábado
df['day_of_week'] = df['start_ts'].dt.dayofweek
df_saturday = df[df['day_of_week'] == 5]  # 5 = sábado

# Paso 4: Dividir en dos grupos según si llovía o no
rainy = df_saturday[df_saturday['weather_conditions'] == 'Bad']
not_rainy = df_saturday[df_saturday['weather_conditions'] == 'Good']

# Paso 5: Prueba t de hipótesis (dos colas, varianzas desiguales)
t_stat, p_value = stats.ttest_ind(
    rainy['duration_seconds'],
    not_rainy['duration_seconds'],
    equal_var=False
)

# Paso 6: Imprimir resultados
print(f"Media sábados lluviosos: {rainy['duration_seconds'].mean():.2f} s")
print(f"Media sábados no lluviosos: {not_rainy['duration_seconds'].mean():.2f} s")
print(f"Valor p: {p_value:.4e}")

# Paso 7: Evaluar hipótesis
alpha = 0.05
if p_value < alpha:
    print("Rechazamos la hipótesis nula: la duración promedio cambia los sábados lluviosos.")
else:
    print("No se puede rechazar la hipótesis nula: no hay diferencias significativas.")
# Out:
# Media sábados lluviosos: 2427.21 s
# Media sábados no lluviosos: 1999.68 s
# Valor p: 6.7390e-12
# Rechazamos la hipótesis nula: la duración promedio cambia los sábados lluviosos.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# Bien hecho!<br/>
# Los datos se separaron correctamente en cada uno de los días buenos y malos.
#
# Es correcto rechazar la hipotesis nula, debido a que sí hay notables cambios entre un día de buenas condiciones y uno con malas condiciones
# </div>

# %% [markdown]
# ## Conclusiones de la Prueba de Hipotesis (Paso 5)
#
# #### Hipótesis planteada:
# > "La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia los sábados lluviosos."
#
# #### Formulación de hipótesis:
#
# - **Hipótesis nula (H₀):** La duración promedio de los viajes los sábados lluviosos es igual a la duración promedio los sábados no lluviosos.
# - **Hipótesis alternativa (H₁):** La duración promedio de los viajes los sábados lluviosos **es diferente** a la de los sábados no lluviosos.
#
# #### Nivel de significancia:
# - Se eligió un valor de alfa = 0.05 (5%) como umbral comúnmente aceptado en pruebas estadísticas.
#
# #### Criterio estadístico usado:
# Se utilizó la **prueba t de Student para muestras independientes** (dos colas), ya que se comparan dos grupos distintos de observaciones (viajes en sábados lluviosos vs no lluviosos) y se desconoce la varianza poblacional.
#
# #### Resultados:
#
# - **Media sábados lluviosos:** 2427.21 s
# - **Media sábados no lluviosos:** 1999.68 s
# - **Valor p:** 6.739e-12
#
# #### Conclusión:
#
# Dado que el valor p es mucho menor que el nivel de significancia (p ≪ 0.05), **rechazamos la hipótesis nula**. Esto indica que **sí existe una diferencia significativa** en la duración promedio de los viajes entre sábados lluviosos y sábados no lluviosos.
# En otras palabras, la duración promedio **cambia** los sábados lluviosos, tal como plantea la hipótesis.

# %% [markdown]
# # Comentario general del revisor
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Has realizado un buen trabajo, me doy cuenta de que has aplicado los conocimientos que has adquirido durante el curso, los procedimientos realizados son correctos, este es un ejercicio que nos ayuda a entender y comprobar las hipotesis con procesos estadisticos.<br/>
# <br/>
# Continúa con el buen trabajo y mucho éxito en el siguiente Sprint!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Aspectos positivos del proyecto</b> <a class="tocSkip"></a><br />
#
# - Las observaciones intermedias, así como las conclusiones finales me parecen bastante detalladas
# - Las graficas utilizadas me parecen del tipo correcto
# - El proyecto esta ordenado
#
# </div>
